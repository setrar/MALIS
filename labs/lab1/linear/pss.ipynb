# %% [markdown]
# ## 1.1 PSS
# $$
# \hat{S}_{PSS,i}(N) = \sum_k x_i(n - kN), i = 0, 1, 2
# $$

# %% [markdown]
# ```mathlab
#
# plot(real(pss0_t))
# subplot(212)
# plot(real(pss0_t))
#
# plot(abs(pss0_t))
# plot(20*log10(abs(pss0_t))
# ```

# %% [markdown]
# ```matlab
# plot(20*log10(abs(pss0_t))
# plot(20*log10(abs(fftshift(fft(pss0_t)))
#
# ```

# %% [markdown]
# thres = max(abs(pss0F))/10;
# length(find(abs(pss0F)>thres))
# 130*61.44e6/2192
# # 127 samples in frequency domain
# # 30e3 (30Khz)
# 127*30e3

# %% [markdown]
# pkg load signal
#
# pss00 = xcorr(pss0_t.pss0_t);

# %%
pss_0 = Complex[
    -363 + 0im,
    362 + 0im,
    362 + 0im,
    -363 + 0im,
    -363 + 0im,
    362 + 0im,
    -363 + 0im,
    362 + 0im,
    362 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    362 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    362 + 0im,
    362 + 0im,
    362 + 0im,
    362 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    362 + 0im,
    362 + 0im,
    362 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    362 + 0im,
    -363 + 0im,
    -363 + 0im,
    362 + 0im,
    362 + 0im,
    362 + 0im,
    -363 + 0im,
    362 + 0im,
    -363 + 0im,
    362 + 0im,
    362 + 0im,
    -363 + 0im,
    362 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
    -363 + 0im,
]

# Printing the first few elements to check
for i in 1:min(10, length(pss_0))
    println(pss_0[i])
end
# Out:
# -363 + 0im
# 362 + 0im
# 362 + 0im
# -363 + 0im
# -363 + 0im
# 362 + 0im
# -363 + 0im
# 362 + 0im
# 362 + 0im
# -363 + 0im

# %%
pss_1 = Complex[362 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      362 + 0im,
                      362 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      362 + 0im,
                      362 + 0im,
                      362 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      -363 + 0im,
                      362 + 0im,
                      -363 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
                      0 + 0im,
]

# Printing the first few elements to check
for i in 1:min(10, length(pss_1))
    println(pss_1[i])
end
# Out:
# 362 + 0im
# 362 + 0im
# -363 + 0im
# 362 + 0im
# -363 + 0im
# -363 + 0im
# -363 + 0im
# -363 + 0im
# -363 + 0im
# 362 + 0im

# %%
pss_2 = Complex[-363 + 0im,
              -363 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              -363 + 0im,
              -363 + 0im,
              362 + 0im,
              -363 + 0im,
              -363 + 0im,
              362 + 0im,
              -363 + 0im,
              362 + 0im,
              -363 + 0im,
              -363 + 0im,
              362 + 0im,
              -363 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              -363 + 0im,
              -363 + 0im,
              362 + 0im,
              362 + 0im,
              -363 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              -363 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              -363 + 0im,
              362 + 0im,
              362 + 0im,
              -363 + 0im,
              362 + 0im,
              362 + 0im,
              -363 + 0im,
              -363 + 0im,
              362 + 0im,
              -363 + 0im,
              362 + 0im,
              362 + 0im,
              -363 + 0im,
              -363 + 0im,
              -363 + 0im,
              -363 + 0im,
              362 + 0im,
              -363 + 0im,
              -363 + 0im,
              -363 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              362 + 0im,
              -363 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
              0 + 0im,
]

# Printing the first few elements to check
for i in 1:min(10, length(pss_2))
    println(pss_2[i])
end
# Out:
# -363 + 0im
# -363 + 0im
# 362 + 0im
# 362 + 0im
# 362 + 0im
# 362 + 0im
# 362 + 0im
# -363 + 0im
# -363 + 0im
# 362 + 0im

# %%
using FFTW  # Make sure to install the FFTW package if not already installed
# using ComplexNumbers  # Import the ComplexNumbers package for complex number support

Nfft = 2048


pss0_t = ifft(pss_0')  # Transpose is not needed in Julia
pss0_t = pss0_t / norm(pss0_t)

# pss1_t = ifft(pss_1')
# pss1_t = pss1_t / norm(pss1_t)

# pss2_t = ifft(pss_2')
# pss2_t = pss2_t / norm(pss2_t)

# pss0_t = vcat(pss0_t[end - 143:end], pss0_t)  # Use vcat to concatenate arrays
# pss1_t = vcat(pss1_t[end - 143:end], pss1_t)
# pss2_t = vcat(pss2_t[end - 143:end], pss2_t)
# Out:
# MethodError: no method matching plan_bfft(::LinearAlgebra.Adjoint{Complex, Vector{Complex}}, ::UnitRange{Int64})
#
# Closest candidates are:
#   plan_bfft(::StridedArray{T, N}, ::Any; flags, timelimit, num_threads) where {T<:Union{ComplexF64, ComplexF32}, N}
#    @ FFTW ~/.julia/packages/FFTW/HfEjB/src/fft.jl:772
#   plan_bfft(::AbstractArray{<:Real}, ::Any; kws...)
#    @ AbstractFFTs ~/.julia/packages/AbstractFFTs/4iQz5/src/definitions.jl:215
#   plan_bfft(::AbstractArray{<:Complex{<:Union{Integer, Rational}}}, ::Any; kws...)
#    @ AbstractFFTs ~/.julia/packages/AbstractFFTs/4iQz5/src/definitions.jl:217
#   ...
#
#
# Stacktrace:
#  [1] plan_ifft(x::LinearAlgebra.Adjoint{Complex, Vector{Complex}}, region::UnitRange{Int64}; kws::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ AbstractFFTs ~/.julia/packages/AbstractFFTs/4iQz5/src/definitions.jl:282
#  [2] plan_ifft(x::LinearAlgebra.Adjoint{Complex, Vector{Complex}}, region::UnitRange{Int64})
# ...
