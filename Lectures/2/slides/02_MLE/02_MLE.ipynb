# %% [markdown]
# # The Maximum Likelihood Estimator (MLE)
#
# $$ * \text{Finding } \hat{\theta} $$

# %% [markdown]
# Eq 1
#
# $$ \hat{\theta} $$
#
# $$ \sum_i^N log( )$$
#
# $$ P({\color{Orange}y}_i|{\color{Bittersweet}x}_i;{\color{Green}w};{\color{YellowGreen}\sigma}^2) = \frac{1}{ {\color{YellowGreen}\sigma} \sqrt{2 \pi } }  exp \Bigg\{ − \frac{({\color{Orange}y}_i − {\color{Green}w}^T {\color{Bittersweet}x}_i)^2}{2 {\color{YellowGreen}\sigma} ^2} \Bigg\} $$

# %%
using Plots

n = 200
x = range(0, stop=2 * π, length=n)

f = exp.(-2 * .√(x))
# f = .√(x)

# y = .√(x)

# f = exp.(-2 * (x .- π + 1) .^ 2)

# approx = zeros(x)
plot(x, f, color="blue", linewidth=2, label="Original")
